# %% [markdown]
# # NAMED ENTITY RECOGNITION:
#
# On Space health and support system

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
data = pd.read_json("/content/drive/MyDrive/Datasets/NLP PROJECT/data.json")

# %%
data.head(30)
# Out:
#     id                                             tokens  \
# 0    1  [Create, a, scatterplot, for, altitude, in, mi...
# 1    2  [Produce, a, heatmap, for, temperature, in, mi...
# 2    3  [Draw, a, boxplot, for, engine, temperature, i...
# 3    4  [Generate, a, bar, chart, for, voltage, in, mi...
# 4    5  [Make, a, lineplot, for, temperature, in, miss...
# 5    6  [Construct, a, scatterplot, of, oxygen, levels...
# 6    7  [Display, a, heatmap, for, solar, power, in, m...
# 7    8  [Visualize, a, bar, chart, for, engine, thrust...
# 8    9  [Construct, a, boxplot, for, temperature, in, ...
# 9   10  [Generate, a, lineplot, for, Temp, in, mission...
# 10  11  [Create, a, scatterplot, for, Voltage, in, mis...
# 11  12  [Produce, a, bar, chart, of, Thrust, in, missi...
# 12  13  [Plot, a, lineplot, for, Pressure, in, mission...
# 13  14  [Visualize, a, scatterplot, of, Voltage, in, m...
# 14  15  [Generate, a, boxplot, for, Temp, in, mission, 1]
# ...

# %%
data['action'] = list(x['ACTION'] for x in list(data['BIO_tags']))
data['table'] = list(x['TABLE'] for x in list(data['BIO_tags']))
data.head()
# Out:
#    id                                             tokens  \
# 0   1  [Create, a, scatterplot, for, altitude, in, mi...
# 1   2  [Produce, a, heatmap, for, temperature, in, mi...
# 2   3  [Draw, a, boxplot, for, engine, temperature, i...
# 3   4  [Generate, a, bar, chart, for, voltage, in, mi...
# 4   5  [Make, a, lineplot, for, temperature, in, miss...
#
#                                             BIO_tags  \
# 0  {'ACTION': ['O', 'O', 'B-ACTION', 'O', 'B-FEAT...
# 1  {'ACTION': ['O', 'O', 'B-ACTION', 'O', 'B-FEAT...
# 2  {'ACTION': ['O', 'O', 'B-ACTION', 'O', 'B-FEAT...
# 3  {'ACTION': ['O', 'O', 'B-ACTION', 'I-ACTION', ...
# 4  {'ACTION': ['O', 'O', 'B-ACTION', 'O', 'B-FEAT...
#
#                                               action  \
# 0  [O, O, B-ACTION, O, B-FEATURE, O, O, O, O, B-F...
# 1  [O, O, B-ACTION, O, B-FEATURE, O, O, O, o, b-F...
# 2  [O, O, B-ACTION, O, B-FEATURE, I-FEATURE, O, O...
# 3  [O, O, B-ACTION, I-ACTION, O, B-FEATURE, O, O,...
# ...

# %%
data['tokens'][0]
# Out:
# ['Create',
#  'a',
#  'scatterplot',
#  'for',
#  'altitude',
#  'in',
#  'mission',
#  '3',
#  'against',
#  'power',
#  'in',
#  'mission',
#  '1']

# %%
tokens = []
actions = []
tables = []
sent = []
j = 0
for i in data['tokens']:
    tokens += i
    sent += [j]*(len(i))
    j += 1

for i in data['action']:
    actions += i

for i in data['table']:
    tables += i

print(len(sent),len(tokens), len(actions), len(tables))
# Out:
# 751 751 751 751

# %%
a = data['tokens']
b = data['table']
c = data['action']

for i in range(len(a)):
  if len(a[i]) != len(b[i]) or len(a[i]) != len(b[i]):
      print(i, a[i])

# %%
df = pd.DataFrame()
df['sent'] = sent
df['tok'] = tokens
df['act'] = [x.upper() for x in actions]
df['tab'] = [x.upper() for x in tables]
df.head()
# Out:
#    sent          tok        act tab
# 0     0       Create          O   O
# 1     0            a          O   O
# 2     0  scatterplot   B-ACTION   O
# 3     0          for          O   O
# 4     0     altitude  B-FEATURE   O

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
X= df[["sent","tok"]]
Y =df["act"]

# %%
x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size =0.2)

# %%
#building up train data and test data
train_data = pd.DataFrame({"sentence_id":x_train["sent"],"words":x_train["tok"],"labels":y_train})
test_data = pd.DataFrame({"sentence_id":x_test["sent"],"words":x_test["tok"],"labels":y_test})

# %%
train_data.head()
# Out:
#      sentence_id    words     labels
# 82             6      for          O
# 260           20  Produce          O
# 676           52        1          O
# 563           43     Temp  B-FEATURE
# 80             6        a          O

# %% [markdown]
# ### Simpletransformers installation

# %%
# !pip install simpletransformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.8/250.8 kB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 35.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.7/493.7 kB 42.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 7.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 83.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 89.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 104.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 85.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 40.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 91.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 39.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### Actions and Features NER Extraction

# %%
from simpletransformers.ner import NERModel,NERArgs

# %%
label_act = df["act"].unique().tolist()
label_act
# Out:
# ['O', 'B-ACTION', 'B-FEATURE', 'I-FEATURE', 'I-ACTION']

# %%
args = NERArgs()
args.num_train_epochs = 20
args.learning_rate = 1e-4
args.overwrite_output_dir =True
args.train_batch_size = 32
args.eval_batch_size = 32

# %%
model_act = NERModel('bert', 'bert-base-cased',labels=label_act,args =args)
# Out:
# ...
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ...

# %%
model_act.train_model(train_data,eval_data = test_data,acc=accuracy_score)
# Out:
# /usr/local/lib/python3.10/dist-packages/simpletransformers/ner/ner_utils.py:190: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   return [
# ...
# Running Epoch 0 of 20:   0%|          | 0/2 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# ...
# Running Epoch 19 of 20:   0%|          | 0/2 [00:00<?, ?it/s]
# ...

# %%
result, model_outputs, preds_list = model_act.eval_model(test_data)
# Out:
# /usr/local/lib/python3.10/dist-packages/simpletransformers/ner/ner_utils.py:190: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   return [
# ...
# Running Evaluation:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
result
# Out:
# {'eval_loss': 0.10091114233364351,
#  'precision': 1.0,
#  'recall': 0.9534883720930233,
#  'f1_score': 0.9761904761904763}

# %%
prediction, model_output = model_act.predict(["show me bar graph of temperATURE V/S pressure"])
# Out:
# ...
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
prediction
# Out:
# [[{'show': 'O'},
#   {'me': 'O'},
#   {'bar': 'B-ACTION'},
#   {'graph': 'O'},
#   {'of': 'O'},
#   {'temperATURE': 'B-FEATURE'},
#   {'V/S': 'O'},
#   {'pressure': 'B-FEATURE'}]]

# %%
label_act.remove('O')

# %%
features = []

for i in prediction[0]:
    for j in i:
        if(i[j] in label_act):
            features.append(j)


print(features)
# Out:
# ['bar', 'temperATURE', 'pressure']

# %% [markdown]
# ### Table NER Extraction

# %%
X= df[["sent","tok"]]
Y =df["tab"]

# %%
x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size =0.2)

# %%
#building up train data and test data
train_data = pd.DataFrame({"sentence_id":x_train["sent"],"words":x_train["tok"],"labels":y_train})
test_data = pd.DataFrame({"sentence_id":x_test["sent"],"words":x_test["tok"],"labels":y_test})

# %%
train_data
# Out:
#      sentence_id      words   labels
# 9              0      power        O
# 557           42    mission  B-TABLE
# 711           55          3  I-TABLE
# 232           17          1  I-TABLE
# 124            9    mission  B-TABLE
# ..           ...        ...      ...
# 633           49         in        O
# 193           15  Construct        O
# 282           21          2  I-TABLE
# 102            7    mission  B-TABLE
# 148           11      chart        O
#
# [600 rows x 3 columns]

# %%
label_tab = df["tab"].unique().tolist()
label_tab
# Out:
# ['O', 'B-TABLE', 'I-TABLE']

# %%
args = NERArgs()
args.num_train_epochs = 20
args.learning_rate = 1e-4
args.overwrite_output_dir =True
args.train_batch_size = 32
args.eval_batch_size = 32

# %%
tab_model = NERModel('bert', 'bert-base-cased',labels=label_tab,args =args)
# Out:
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
tab_model.train_model(train_data,eval_data = test_data,acc=accuracy_score)
# Out:
# /usr/local/lib/python3.10/dist-packages/simpletransformers/ner/ner_utils.py:190: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   return [
# ...
# Running Epoch 0 of 20:   0%|          | 0/2 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# ...
# Running Epoch 19 of 20:   0%|          | 0/2 [00:00<?, ?it/s]
# ...

# %%
result, model_outputs, preds_list = tab_model.eval_model(test_data)
# Out:
# /usr/local/lib/python3.10/dist-packages/simpletransformers/ner/ner_utils.py:190: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   return [
# ...
# Running Evaluation:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
result
# Out:
# {'eval_loss': 6.857083280920051e-05,
#  'precision': 1.0,
#  'recall': 1.0,
#  'f1_score': 1.0}

# %%
prediction, model_output = tab_model.predict(["show me bar graph of temperATURE for mission 2 V/S pressure for mission 1"])
# Out:
# ...
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
prediction
# Out:
# [[{'show': 'O'},
#   {'me': 'O'},
#   {'bar': 'O'},
#   {'graph': 'O'},
#   {'of': 'O'},
#   {'temperATURE': 'O'},
#   {'for': 'O'},
#   {'mission': 'B-TABLE'},
#   {'2': 'I-TABLE'},
#   {'V/S': 'O'},
#   {'pressure': 'O'},
#   {'for': 'O'},
#   {'mission': 'B-TABLE'},
#   {'1': 'I-TABLE'}]]

# %%
label_tab.remove('O')

# %%
tabs = []

for i in prediction[0]:
    for j in i:
        if(i[j] in label_tab):
            tabs.append(j)

tabs
# Out:
# ['mission', '2', 'mission', '1']

# %%
print("Features ", features)
print("Tables ", tabs)
# Out:
# Features  ['bar', 'temperATURE', 'pressure']
# Tables  ['mission', '2', 'mission', '1']
